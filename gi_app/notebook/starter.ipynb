# %% [markdown]
# # GI Cancer — QC / feasibility starter
#
# Connects to Postgres via the shared DB layer (`/shared` on `PYTHONPATH`).

# %%
import pandas as pd
from Database.database import engine

pd.read_sql('SELECT * FROM dataset_stats', engine)

# %%
pd.read_sql('SELECT vital_status, COUNT(*) FROM cases GROUP BY vital_status', engine)
